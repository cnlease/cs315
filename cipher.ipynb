# %% [markdown]
# <a href="https://colab.research.google.com/github/cnlease/cs315/blob/main/cipher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

char_code = int(3)
print(chr(char_code))

# %%
message="h i a l l"
message = message.split()
encrypted= ""
for i in message:
  encrypted = encrypted + int(i) + " "
print(encrypted)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3961125925.py in <cell line: 0>()
#       3 encrypted= ""
#       4 for i in message:
# ----> 5   encrypted = encrypted + int(i) + " "
#       6 print(encrypted)
#
# ValueError: invalid literal for int() with base 10: 'h'
